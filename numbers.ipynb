# %% [markdown]
# ## Numbers

# %% [markdown]
# ## Integers

# %%
2+3
# Out:
# 5

# %%
2*3
# Out:
# 6

# %%
3/2
# Out:
# 1.5

# %%
2-3
# Out:
# -1

# %%
# exponents
2 ** 3
# Out:
# 8

# %%
# order of operations
2 + 3*4
# Out:
# 14

# %%
(2+3)*4
# Out:
# 20

# %% [markdown]
# ## float

# %% [markdown]
# -  Python calls any number with a decimal point a float

# %%
0.1 + 0.1
# Out:
# 0.2

# %%
# sometimes you will get arbitrary number of values
print(0.1 + 0.2)
print(3 * 0.1)

# this is due to how computers represents number internally
# Out:
# 0.30000000000000004
# 0.30000000000000004

# %% [markdown]
# ## Integers and Float

# %% [markdown]
# - When you divide any two numbers, even if they are integers that result in a
# whole number, you’ll always get a float

# %%
4/2
# Out:
# 2.0

# %% [markdown]
# -  If you mix an integer and a float in any other operation, you’ll get a
# float as well
# - Python defaults to a float in any operation that uses a float, even if the
# output is a whole number.

# %%
2 * 0.1
# Out:
# 0.2

# %% [markdown]
# ## underscores in numbers

# %%
# more readable
universe_age = 1_000_000_000 #python ignores the _ in integers and float
print(universe_age)
# Out:
# 1000000000

# %% [markdown]
# ### multiple assignments

# %%
x, y, z = 10, 20, 30
print(x,y,z)
# Out:
# 10 20 30

# %% [markdown]
# ## Constants
#
# - python doesn't have built in constant types
# - All in uppercase

# %%
MAX_CONNECTIONS = 5000
