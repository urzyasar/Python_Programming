# %% [markdown]
#  Programming often involves examining
# a set of conditions and deciding which
# action to take based on those conditions.
# Python’s if statement allows you to examine
# the current state of a program and respond appro
# priately to that state.

# %%
cars = ['audi', 'bmw', 'subaru', 'toyota']
for car in cars:
    if car == 'bmw':
        print(car.upper())
    else:
        print(car.title())
# Out:
# Audi
# BMW
# Subaru
# Toyota

# %% [markdown]
# ## Conditional Tests

# %%
car = 'audi'
car == 'bmw'
# Out:
# False

# %% [markdown]
# ###  Ignoring Case When Checking for Equality
# - Testing for equality is case sensitive. For example, the following code returns False because 'Audi' (with a capital A) is not the same as 'audi' (all lowercase):
# car = 'Audi'

# %%
car = 'Audi'
car.lower() == 'audi'
# Out:
# True

# %% [markdown]
# ## Checking for Inequality

# %%
requested_topping = 'mushrooms'
if requested_topping != 'anchovies':
    print("Hold the anchovies!")
# Out:
# Hold the anchovies!

# %% [markdown]
# ###  Numerical Comparisons

# %%
age = 19
print(age < 21)
print(age <= 21)
# Out:
# True
# True

# %% [markdown]
# ###  Checking Multiple Conditions

# %%
age_0 = 22
age_1 = 18
age_0 >= 21 and age_1 >= 21
# Out:
# False

# %%
age_1 = 22
(age_0 >= 21) or (age_1 >= 21) # Added parentheses for clarity
# Out:
# True

# %%
# Using or to Check Multiple Conditions
(age_0 >= 21) or (age_1 >= 21)
# Out:
# True

# %% [markdown]
# ### Checking Whether a Value Is in a List

# %%
requested_toppings = ['mushrooms', 'onions', 'pineapple']
'mushrooms' in requested_toppings
# Out:
# True

# %%
'pepperoni' in requested_toppings
# Out:
# False

# %%
banned_users = ['andrew', 'carolina', 'david']
user = 'marie'
if user not in banned_users:
    print(f"{user.title()}, you can post a response if you wish.")
# Out:
# Marie, you can post a response if you wish.

# %%
age = 19
if age >= 18:
    print("You are old enough to vote!")
# Out:
# You are old enough to vote!

# %% [markdown]
# ###  if-else Statements

# %%
age = 17
if age >= 18:
    print("You are old enough to vote!")
    print("Have you registered to vote yet?")
else:
    print("Sorry, you are too young to vote.")
    print("Please register to vote as soon as you turn 18!")
# Out:
# Sorry, you are too young to vote.
# Please register to vote as soon as you turn 18!

# %% [markdown]
# ###  The if-elif-else Chain
# - Python executes only one
# block in an if-elif-else chain. It runs each conditional test in order, until
# one passes. When a test passes, the code following that test is executed and
# Python skips the rest of the tests.

# %%
age = 12
if age < 4:
    print("Your admission cost is $0.")
elif age < 18:
    print("Your admission cost is $25.")
else:
    print("Your admission cost is $40.")
# Out:
# Your admission cost is $25.

# %%
age = 12
if age < 4:
    price = 0
elif age < 18:
    price = 25
else:
    price = 40
print(f"Your admission cost is ${price}.")
# Out:
# Your admission cost is $25.

# %%
## Omitting the else Block
age = 12
if age < 4:
    price = 0
elif age < 18:
    price = 25
elif age < 65:
    price = 40
elif age >= 65:
    price = 20
print(f"Your admission cost is ${price}.")
# Out:
# Your admission cost is $25.

# %%
# sometimes you no need skip after first true condition

requested_toppings = ['mushrooms', 'extra cheese']
if 'mushrooms' in requested_toppings:
    print("Adding mushrooms.")
if 'pepperoni' in requested_toppings:
    print("Adding pepperoni.")
if 'extra cheese' in requested_toppings:
    print("Adding extra cheese.")
print("\nFinished making your pizza!")
# Out:
# Adding mushrooms.
# Adding extra cheese.
#
# Finished making your pizza!

# %% [markdown]
# In summary, if you want only one block of code to run, use an if-elif-else
# chain. If more than one block of code needs to run, use a series of indepen
# dent if statements.

# %% [markdown]
# ##  Using if Statements with Lists

# %%
 requested_toppings = ['mushrooms', 'green peppers', 'extra cheese']
 for requested_topping in requested_toppings:
    if requested_topping == 'green peppers':
         print("Sorry, we are out of green peppers right now.")
    else:
        print(f"Adding {requested_topping}.")
 print("\nFinished making your pizza!")
# Out:
# Adding mushrooms.
# Sorry, we are out of green peppers right now.
# Adding extra cheese.
#
# Finished making your pizza!

# %%
# check whether a list is empty
requested_toppings = []
if requested_toppings:
    for requested_topping in requested_toppings:
        print(f"Adding {requested_topping}.")
    print("\nFinished making your pizza!")
else:
    print("Are you sure you want a plain pizza?")
# Out:
# Are you sure you want a plain pizza?

# %%
# using multiple lists
available_toppings = ['mushrooms', 'olives', 'green peppers',
                      'pepperoni', 'pineapple', 'extra cheese']
requested_toppings = ['mushrooms', 'french fries', 'extra cheese']

for requested_topping in requested_toppings:
    if requested_topping in available_toppings:
        print(f"Adding {requested_topping}.")
    else:
        print(f"Sorry, we don't have {requested_topping}.")
print("\nFinished making your pizza!")
# Out:
# Adding mushrooms.
# Sorry, we don't have french fries.
# Adding extra cheese.
#
# Finished making your pizza!
