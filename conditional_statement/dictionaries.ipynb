# %% [markdown]
# - A dictionary in Python is a collection of key-value pairs.
# - Each key is connected to
# a value, and you can use a key to access the value associated with that key.
# - A key’s value can be a number, a string, a list, or even another dictionary.
# -  Dictionaries retain the order in which they were defined.

# %%
# a simple dictionary example
alien_0 = {'color': 'green', 'points': 5}
print(alien_0['color'])
print(alien_0['points'])
# Out:
# green
# 5

# %% [markdown]
# # Accessing values in a dictionary
# - To get the value associated with a key, give the name of the dictionary and
# then place the key inside a set of square brackets,

# %%
alien_0 = {'color': 'green'}
alien_0['color']
# Out:
# 'green'

# %% [markdown]
# #  Adding New Key-Value Pairs
# - To add a new key-value pair, you would give the
# name of the dictionary followed by the new key in square brackets, along
# with the new value.

# %%
alien_0 = {'color': 'green', 'points': 5}
print(alien_0)
alien_0['x_position'] = 0
alien_0['y_position'] = 25
print(alien_0)
# Out:
# {'color': 'green', 'points': 5}
# {'color': 'green', 'points': 5, 'x_position': 0, 'y_position': 25}

# %%
# Starting with an Empty Dictionary
alien_0 = {}
alien_0['color'] = 'green'
alien_0['points'] = 5

print(alien_0)
# Out:
# {'color': 'green', 'points': 5}

# %% [markdown]
# #  Modifying Values in a Dictionary
# - To modify a value in a dictionary, give the name of the dictionary with the
# key in square brackets and then the new value you want associated with
# that key.

# %%
alien_0 = {'color': 'green'}
print(f"The alien is {alien_0['color']}.")

alien_0['color'] = 'yellow'
print(f"The alien is now {alien_0['color']}.")
# Out:
# The alien is green.
# The alien is now yellow.

# %%
alien_0 = {'x_position': 0, 'y_position': 25, 'speed': 'medium'}
print(f"Original position: {alien_0['x_position']}")
# Move the alien to the right.
# Determine how far to move the alien based on its current speed.
if alien_0['speed'] == 'slow':
    x_increment = 1
elif alien_0['speed'] == 'medium':
    x_increment = 2
else:
    # This must be a fast alien.
    x_increment = 3
# The new position is the old position plus the increment.
alien_0['x_position'] = alien_0['x_position'] + x_increment
print(f"New position: {alien_0['x_position']}")
# Out:
# Original position: 0
# New position: 2

# %% [markdown]
# # Removing Key-Value Pairs
# - All del needs is the name of the dictionary and the key that you want to
# remove.

# %%
alien_0 = {'color': 'green', 'points': 5}
print(alien_0)

del alien_0['points']
print(alien_0)
# Out:
# {'color': 'green', 'points': 5}
# {'color': 'green'}

# %%
# can store different sets of information about individuals
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'rust',
    'phil': 'python',
    }
language = favorite_languages['sarah'].title()
print(f"Sarah's favorite language is {language}.")
# Out:
# Sarah's favorite language is C.

# %%
 alien_0 = {'color': 'green', 'speed': 'slow'}
 print(alien_0['points']) # this will cause a KeyError if 'points' is not a key in alien_0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 2
#       1 alien_0 = {'color': 'green', 'speed': 'slow'}
# ----> 2 print(alien_0['points']) # this will cause a KeyError if 'points' is not a key in alien_0
#
# KeyError: 'points'

# %%
# Using get() to Access Values with a Default Value
alien_0 = {'color': 'green', 'speed': 'slow'}
point_value = alien_0.get('points', 'No point value assigned.')
print(point_value)
# Out:
# No point value assigned.

# %%
point_value = alien_0.get('points') # returns None if 'points' key is not found
print(point_value)
# Out:
# None

# %% [markdown]
# # looping through a dictionary

# %% [markdown]
# 1.  Looping Through All Key-Value Pairs

# %%
user_0 = {
    'username': 'efermi',
    'first': 'enrico',
    'last': 'fermi',
    }

# %%
for key, value in user_0.items():
    print(f"\nkey: {key}")
    print(f"value: {value}")
print(f"key and value: {key}: {value} is still accessible outside the loop as python is not using block scope.")
# Out:
# key: username
# value: efermi
#
# key: first
# value: enrico
#
# key: last
# value: fermi
# key and value: last: fermi is still accessible outside the loop as python is not using block scope.

# %%
# perfectly works for same kind of information for many different keys.
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'rust',
    'phil': 'python',
    }
for name, language in favorite_languages.items():
    print(f"{name.title()}'s favorite language is {language.title()}.")
# Out:
# Jen's favorite language is Python.
# Sarah's favorite language is C.
# Edward's favorite language is Rust.
# Phil's favorite language is Python.

# %% [markdown]
# # Looping Through All the Keys in a Dictionary
# - The keys() method is useful when you don’t need to work with all of the val
# ues in a dictionary

# %%
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'rust',
    'phil': 'python',
    }
for name in favorite_languages.keys():
    print(name.title())
# Out:
# Jen
# Sarah
# Edward
# Phil

# %%
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'rust',
    'phil': 'python',
    }
friends = ['phil', 'sarah']
for name in favorite_languages.keys():
    print(f"Hi {name.title()}.")
    if name in friends:
       language = favorite_languages[name].title()
       print(f"\t{name.title()}, I see you love {language}!")
# Out:
# Hi Jen.
# Hi Sarah.
# 	Sarah, I see you love C!
# Hi Edward.
# Hi Phil.
# 	Phil, I see you love Python!

# %%
if 'erin' not in favorite_languages.keys():
    print("Erin, please take our poll!")
# Out:
# Erin, please take our poll!

# %% [markdown]
# ### Looping Through a Dictionary’s Keys in a Particular Order
# - Looping through a dictionary returns the items in the same order they
# were inserted.

# %%
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'rust',
    'phil': 'python',
    }
for name in sorted(favorite_languages.keys()):
    print(f"{name.title()}, thank you for taking the poll.")
# Out:
# Edward, thank you for taking the poll.
# Jen, thank you for taking the poll.
# Phil, thank you for taking the poll.
# Sarah, thank you for taking the poll.

# %% [markdown]
# #  Looping Through All Values in a Dictionary

# %%
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'rust',
    'phil': 'python',
    }
print("The following languages have been mentioned:")
for language in set(favorite_languages.values()): # the set() function removes duplicates
    print(language.title())
# Out:
# The following languages have been mentioned:
# Python
# C
# Rust

# %% [markdown]
# # Set
# - nothing but unique values
# - syntax: my_set = {value1, value2, value3}
# - without key-value pairs

# %% [markdown]
# ## Nesting
# -  Sometimes you’ll want to store multiple dictionaries in a list, or a list of
# items as a value in a dictionary. This is called nesting.

# %%
# A list of dictionaries
alien_0 = {'color': 'green', 'points': 5}
alien_1 = {'color': 'yellow', 'points': 10}
alien_2 = {'color': 'red', 'points': 15}

aliens = [alien_0, alien_1, alien_2]
for alien in aliens:
    print(alien)
# Out:
# {'color': 'green', 'points': 5}
# {'color': 'yellow', 'points': 10}
# {'color': 'red', 'points': 15}

# %%
# Make an empty list for storing aliens.
aliens = []

for alien_number in range(30):
    new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
    aliens.append(new_alien)

for alien in aliens[:3]:
    if alien['color'] == 'green':
        alien['color'] = 'yellow'
        alien['speed'] = 'medium'
        alien['points'] = 10
    elif alien['color'] == 'yellow':
        alien['color'] = 'red'
        alien['speed'] = 'fast'
        alien['points'] = 15

# show first 5
for alien in aliens[:5]:
    print(alien)
print("...")

# show how many aliens have been created
print(f"Total number of aliens: {len(aliens)}")
# Out:
# {'color': 'yellow', 'points': 10, 'speed': 'medium'}
# {'color': 'yellow', 'points': 10, 'speed': 'medium'}
# {'color': 'yellow', 'points': 10, 'speed': 'medium'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# ...
# Total number of aliens: 30

# %% [markdown]
# #  A List in a Dictionary
# - Rather than putting a dictionary inside a list, it’s sometimes useful to put
# a list inside a dictionary

# %%
# Store information about a pizza being ordered.
pizza = {
    'crust': 'thick',
    'toppings': ['mushrooms', 'extra cheese'],
    }

 # Summarize the order.
print(f"You ordered a {pizza['crust']}-crust pizza "
    "with the following toppings:")
for topping in pizza['toppings']:
    print(f"\t{topping}")
# Out:
# You ordered a thick-crust pizza with the following toppings:
# 	mushrooms
# 	extra cheese

# %%
favorite_languages = {
 'jen': ['python', 'rust'],
 'sarah': ['c'],
    'edward': ['rust', 'go'],
    'phil': ['python', 'haskell'],
    }
for name, languages in favorite_languages.items():
    print(f"\n{name.title()}'s favorite languages are:")
 
    for language in languages:
        print(f"\t{language.title()}")
# Out:
# Jen's favorite languages are:
# 	Python
# 	Rust
#
# Sarah's favorite languages are:
# 	C
#
# Edward's favorite languages are:
# 	Rust
# 	Go
#
# Phil's favorite languages are:
# 	Python
# 	Haskell

# %% [markdown]
# ## A Dictionary in a Dictionary

# %%
users = {
    'aeinstein': {
        'first': 'albert',
        'last': 'einstein',
        'location': 'princeton',
        },
    'mcurie': {
        'first': 'marie',
        'last': 'curie',
        'location': 'paris',
        },
    }
for username, user_info in users.items():
 
    print(f"\nUsername: {username}")
 
 
    full_name = f"{user_info['first']} {user_info['last']}"
    location = user_info['location']
    print(f"\tFull name: {full_name.title()}")
    print(f"\tLocation: {location.title()}")
# Out:
# Username: aeinstein
# 	Full name: Albert Einstein
# 	Location: Princeton
#
# Username: mcurie
# 	Full name: Marie Curie
# 	Location: Paris
