# %% [markdown]
# # strings

# %% [markdown]
# A string is a series of characters. Anything inside quotes is considered
# a string in Python, and you can use single or double quotes around your
# strings like this:
#  "This is a string."
#  'This is also a string.'

# %%
name = "ada lovelace"
print(name.title())
print(name.upper())
print(name.lower())
# Out:
# Ada Lovelace
# ADA LOVELACE
# ada lovelace

# %%
first_name = "yasar"
last_name = "arafath"
full_name = f"{first_name} {last_name}"
print(full_name)
print(f"Hello!, {full_name.title()}")
# Out:
# yasar arafath
# Hello!, Yasar Arafath

# %% [markdown]
#  - Adding whitespace

# %%
print("python")
print("\tpython") #tab spa
print("Languages:\nPython\nC\nJavaScript") # new line
print("Languages:\n\tPython\n\tC\n\tJavaScript") # new line
# Out:
# python
# 	python
# Languages:
# Python
# C
# JavaScript
# Languages:
# 	Python
# 	C
# 	JavaScript

# %% [markdown]
# ## stripping whitespace

# %%
fav_language = "python " #extra space
print(fav_language)
print(fav_language.rstrip())
fav_language = " python"
print(fav_language)
print(fav_language.lstrip())
# Out:
# python
# python
#  python
# python

# %% [markdown]
# ### Removing Prefixes

# %%
nostarch_url = 'https://nostarch.com'
nostarch_url.removeprefix('https://')
# Out:
# 'nostarch.com'
